# %% [markdown]
# <a href="https://qworld.net" target="_blank" align="left"><img src="../qworld/images/header.jpg"  align="left"></a>

# %% [markdown]
# <font style="font-size:28px;" align="left"><b> A Game with two biased coins  </b></font>
# <br>
# _prepared by Abuzer Yakaryilmaz_
# <br><br>
# [<img src="../qworld/images/watch_lecture.jpg" align="left">](https://youtu.be/k0OJvv7AAgU)
# <br><br><br>

# %% [markdown]
# ## Probabilistic bits
#
# We start with a short introduction to the probabilistic bits to trace the details of the game below.
#
# Suppose that we have a biased coin landing on heads with probability $ 0.3 $, and it is tossed once but we do not see the outcome.
#
# Even though it lands on either heads or tails, our information about the outcome is probabilistic: It is heads with probability $ 0.3 $ and tails with probablity $ 0.7 $.
#
# If we consider this coin as a system with two states (heads and tails: respectively, states 0 and 1), then we can say that after one iteration it is in states 0 and 1 with probabilities 0.3 and 0.7, respectively.
#
# In general, a probabilistic bit is in states 0 and 1 with probabilities $ p $ and $ 1-p $, where $ p $ is a number between 0 and 1. Remark that if $  p=1 $ or $ p=0 $, then the bit becomes deterministic.
#
# If the above biased coin is tossed once more, the probabilisties of the getting heads and tails (or being in the states in 0 and 1) will still be the same. In the following game, by using two biased-coins, we will be able to have different probabilities for the states 0 and 1. This game is our first step to define a probabilitic operator for probabilistic bits.

# %% [markdown]
# ## The game

# %% [markdown]
# Our friend Asja has one euro and one cent.
#
# Both coins are biased, and the probabilities of getting heads and tails are as follows:
# <ul>
#     <li> one euro: heads with probability $ 0.6 $ and tails with probability $ 0.4 $. </li>
#     <li> one cent: heads with probability $ 0.3 $ and tails with probability $ 0.7 $. </li>
# </ul>
#
# Asja flips her coins based on the following <b>protocol</b>:
# <ol>
#     <li> she starts with flipping one euro[*]; </li>
#     <li> whenever she gets heads, she flips one euro in the next round; and, </li>
#     <li> whenever she gets tails, she flips one cent in the next round. </li>
# </ol>
#
# By using a single bit, we summarize all transitions of this game as follows:
#
# $
# GameCoins = \begin{array}{c|cc} \hookleftarrow & \mathbf{Head} & \mathbf{Tail} \\ \hline \mathbf{Head} & 0.6 & 0.3\\  \mathbf{Tail} & 0.4 & 0.7  \end{array} = \begin{array}{c|cc} \hookleftarrow & \mathbf{0} & \mathbf{1} \\ \hline \mathbf{0} & 0.6 & 0.3 \\  \mathbf{1} & 0.4 & 0.7  \end{array}
# $
#
# [*] We should fix an initial condition. Otherwise, Asja cannot pick any of the coins at the beginning of game.

# %% [markdown]
# <h3>Task 1: Convince yourself </h3>
#
# Convince yourself about the correctness of transitions given in the table.
#
# <i> Remark that there is no difference between getting heads from the one euro coin or from the one cent coin.
#
# Therefore, one bit is enough to represent all transitions.
# </i>

# %% [markdown]
# <h3> Tracing Asja's three coin tosses </h3>
#
# Suppose that Asja <b>secretly</b> tosses her coins based on the defined protocol.
#
# By using python, we can calculate the probabilities of Asja seeing heads and tails after three coin tosses.
#
# <i><b>Remark:</b> In the previous tasks of [Coin Flipping](CS08_Coin_Flip.ipynb), we know the ideal ratios, and we experiment many coin tosses and then expect to observe the results close to the ideal ratios.
#
# Here we calculate the exact probabilities (the ideal ratio) by using python. (We will not do the experiments as in the previous tasks.)
# </i>
#
# We present our solution step by step.

# %%
#
# OUR SOLUTION

# initial condition:
# Asja will start with one euro,
#    and so, we assume that the probability of having head is 1 at the beginning.
prob_head = 1
prob_tail = 0

#
# first coin-flip
#

# the new probability of head is calculated by using the first row of table
new_prob_head = prob_head * 0.6 + prob_tail * 0.3

# the new probability of tail is calculated by using the second row of the table
new_prob_tail = prob_head * 0.4 + prob_tail * 0.7

# update the probabilities for the second round
prob_head = new_prob_head
prob_tail = new_prob_tail

#
# second coin-flip
#
# we do the same calculations

new_prob_head = prob_head * 0.6 + prob_tail * 0.3
new_prob_tail = prob_head * 0.4 + prob_tail * 0.7

prob_head = new_prob_head
prob_tail = new_prob_tail

#
# third coin-flip
#
# we do the same calculations

new_prob_head = prob_head * 0.6 + prob_tail * 0.3
new_prob_tail = prob_head * 0.4 + prob_tail * 0.7

prob_head = new_prob_head
prob_tail = new_prob_tail

# print prob_head and prob_tail
print("the probability of getting head after 3 coin tosses is",prob_head)
print("the probability of getting tail after 3 coin tosses is",prob_tail)

# %% [markdown]
# <h3> Task 2: Tracing ten biased coin tosses </h3>
#
# By using python, calculate the probabilities of Asja seeing heads and tails after 10 coin tosses.
#
# $
# GameCoins = \begin{array}{c|cc} \hookleftarrow & \mathbf{Head} & \mathbf{Tail} \\ \hline \mathbf{Head} & 0.6 & 0.3\\  \mathbf{Tail} & 0.4 & 0.7  \end{array} = \begin{array}{c|cc} \hookleftarrow & \mathbf{0} & \mathbf{1} \\ \hline \mathbf{0} & 0.6 & 0.3 \\  \mathbf{1} & 0.4 & 0.7  \end{array}
# $
#
# Use a loop in your solution.

# %%
#
# your solution is here
#
prob_head = 1
prob_tail = 0
for i in range(10):
    prob_head = prob_head * 0.6 + prob_tail * 0.3
    prob_tail = prob_head * 0.4 + prob_tail * 0.7

print("the probability of getting head after 10 coin tosses is",prob_head)
print("the probability of getting tail after 10 coin tosses is",prob_tail)
# Out:
# the probability of getting head after 10 coin tosses is 0.31046262205601144
# the probability of getting tail after 10 coin tosses is 0.4137224267663928

# %% [markdown]
# <a href="CS12_Coin_Flip_Game_Solutions.ipynb#task2">click for our solution</a>

# %% [markdown]
# <h3> Task 3</h3>
#
# Repeat Task 2 for 20, 30, and 50 coin tosses.

# %%
#
# your solution is here
#
for n in [20,30,50]:
    prob_head = 1
    prob_tail = 0
    for i in range(n):
        prob_head = prob_head * 0.6 + prob_tail * 0.3
        prob_tail = prob_head * 0.4 + prob_tail * 0.7

    print("the probability of getting head after ",n," coin tosses is",prob_head)
    print("the probability of getting tail after ",n," coin tosses is",prob_tail)
    print()
# Out:
# the probability of getting head after  20  coin tosses is 0.31034484770573545
# the probability of getting tail after  20  coin tosses is 0.41379309137655823
#
# the probability of getting head after  30  coin tosses is 0.310344827589643
# the probability of getting tail after  30  coin tosses is 0.4137931034462135
#
# the probability of getting head after  50  coin tosses is 0.3103448275862064
# the probability of getting tail after  50  coin tosses is 0.41379310344827513

# %% [markdown]
# <a href="CS12_Coin_Flip_Game_Solutions.ipynb#task3">click for our solution</a>

# %% [markdown]
# <h3> Task 4</h3>
#
# Repeat Task 2 for 10, 20, and 50 coin tosses by picking different initial conditions, e.g.,
#
#     prob_head = prob_tail = 1/2
# or
#
#     prob_head = 0
#     prob_tail = 1

# %%
#
# your solution is here
#
for n in [10,20,50]:
    prob_head = 1/2
    prob_tail = 1/2
    for i in range(n):
        prob_head = prob_head * 0.6 + prob_tail * 0.3
        prob_tail = prob_head * 0.4 + prob_tail * 0.7

    print("the probability of getting head after ",n," coin tosses is",prob_head)
    print("the probability of getting tail after ",n," coin tosses is",prob_tail)
    print()
# Out:
# the probability of getting head after  10  coin tosses is 0.4138078277570012
# the probability of getting tail after  10  coin tosses is 0.5517153033457989
#
# the probability of getting head after  20  coin tosses is 0.4137931059632166
# the probability of getting tail after  20  coin tosses is 0.5517241364220693
#
# the probability of getting head after  50  coin tosses is 0.41379310344827513
# the probability of getting tail after  50  coin tosses is 0.5517241379310335

# %% [markdown]
# <a href="CS12_Coin_Flip_Game_Solutions.ipynb#task4">click for our solution</a>

# %% [markdown]
# <hr>

# %% [markdown]
# <h3> Extra: Arbitrary transitions for GameCoins</h3>
#
# By changing the bias of each Asja's coin, we can define arbitrary GameCoins.
#
# If $ a $ is the probability of getting heads for one euro and $ b $ is the probability of getting heads for one cent, then we have the following transitions:
#
# $
# GameCoins(a,b) = \begin{array}{c|cc} \hookleftarrow & \mathbf{Head} & \mathbf{Tail} \\ \hline \mathbf{Head} & a & b\\  \mathbf{Tail} & 1-a & 1-b  \end{array} = \begin{array}{c|cc} \hookleftarrow & \mathbf{0} & \mathbf{1} \\ \hline \mathbf{0} & a & b \\  \mathbf{1} & 1-a & 1-b  \end{array}
# $

# %% [markdown]
# <h3> Task 5 </h3>
#
# Observe that if $ a=1 $ and $ b = 0 $, then it is Identity operator, i.e., the initial condition will stay as it is.
#
# If $ a=0 $ and $ b=1 $, then it is NOT operator. NOT operator swaps the probabilities of heads and tails in each step. If the initial probabilities are not $ 0.5 $ and $ 0.5 $, then the system never converges to a fixed probabilities.

# %%
#
# your solution is here
#
prob_head = 0.6
prob_tail = 0.4

print('Identity operator')
a = 1
b = 0
prob_head = prob_head * a + prob_tail * b
prob_tail = prob_head * (1-a) + prob_tail * (1-b)
print("the probability of getting head after 1 coin toss is",prob_head)
print("the probability of getting tail after 1 coin toss is",prob_tail)

print()

print('Negation operator')
a = 0
b = 1
prob_head = prob_head * a + prob_tail * b
prob_tail = prob_head * (1-a) + prob_tail * (1-b)
print("the probability of getting head after 1 coin toss is",prob_head)
print("the probability of getting tail after 1 coin toss is",prob_tail)
# Out:
# Identity operator
# the probability of getting head after 1 coin toss is 0.6
# the probability of getting tail after 1 coin toss is 0.4
#
# Negation operator
# the probability of getting head after 1 coin toss is 0.4
# the probability of getting tail after 1 coin toss is 0.4

# %% [markdown]
# <h3> Task 6</h3>
#
# Randomly pick the values of $ a $ and $ b $, and then implement Tasks 3 and 4 for $ GameCoins(a,b) $.

# %%
#
# your solution is here
#
from random import randrange
a = randrange(10)/10
b = randrange(10)/10

def GameCoins(a,b):
    print('Task 3')
    for n in [20,30,50]:
        prob_head = 1
        prob_tail = 0
        for i in range(n):
            prob_head = prob_head * a + prob_tail * b
            prob_tail = prob_head * (1-a) + prob_tail * (1-b)

        print("the probability of getting head after ",n," coin tosses is",prob_head)
        print("the probability of getting tail after ",n," coin tosses is",prob_tail)
        print()

    print('\nTask 4')
    for n in [10,20,50]:
        prob_head = 1/2
        prob_tail = 1/2
        for i in range(n):
            prob_head = prob_head * a + prob_tail * b
            prob_tail = prob_head * (1-a) + prob_tail * (1-b)

        print("the probability of getting head after ",n," coin tosses is",prob_head)
        print("the probability of getting tail after ",n," coin tosses is",prob_tail)
        print()

GameCoins(a,b)
# Out:
# Task 3
# the probability of getting head after  20  coin tosses is 0.25531914893617
# the probability of getting tail after  20  coin tosses is 0.22340425531914876
#
# the probability of getting head after  30  coin tosses is 0.25531914893617
# the probability of getting tail after  30  coin tosses is 0.22340425531914876
#
# the probability of getting head after  50  coin tosses is 0.25531914893617
# the probability of getting tail after  50  coin tosses is 0.22340425531914876
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 0.5531914893616698
# the probability of getting tail after  10  coin tosses is 0.4840425531914988
#
# the probability of getting head after  20  coin tosses is 0.5531914893617019
# the probability of getting tail after  20  coin tosses is 0.48404255319148914
#
# the probability of getting head after  50  coin tosses is 0.5531914893617019
# the probability of getting tail after  50  coin tosses is 0.48404255319148914

# %% [markdown]
# <h3> Task 7</h3>
#
# 10 times repeat Task 6 and observe whether the probabilities converge in each time.

# %%
#
# your solution is here
#
for i in range(10):
    print('Round ',i+1,':')
    a = randrange(10)/10
    b = randrange(10)/10
    print('a = ',a,'\tb = ',b)
    GameCoins(a,b)
    print()
# Out:
# Round  1 :
# a =  0.1 	b =  0.3
# Task 3
# the probability of getting head after  20  coin tosses is 0.032258064516129004
# the probability of getting tail after  20  coin tosses is 0.09677419354838702
#
# the probability of getting head after  30  coin tosses is 0.032258064516129004
# the probability of getting tail after  30  coin tosses is 0.09677419354838702
#
# the probability of getting head after  50  coin tosses is 0.032258064516129004
# the probability of getting tail after  50  coin tosses is 0.09677419354838702
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 0.17741935483962085
# the probability of getting tail after  10  coin tosses is 0.5322580645160377
#
# the probability of getting head after  20  coin tosses is 0.17741935483870958
# the probability of getting tail after  20  coin tosses is 0.5322580645161288
#
# the probability of getting head after  50  coin tosses is 0.17741935483870958
# the probability of getting tail after  50  coin tosses is 0.5322580645161288
#
#
# Round  2 :
# a =  0.5 	b =  0.9
# Task 3
# the probability of getting head after  20  coin tosses is 0.4736842105263157
# the probability of getting tail after  20  coin tosses is 0.26315789473684204
#
# the probability of getting head after  30  coin tosses is 0.4736842105263157
# the probability of getting tail after  30  coin tosses is 0.26315789473684204
#
# the probability of getting head after  50  coin tosses is 0.4736842105263157
# the probability of getting tail after  50  coin tosses is 0.26315789473684204
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 0.710526315789453
# the probability of getting tail after  10  coin tosses is 0.3947368421052734
#
# the probability of getting head after  20  coin tosses is 0.7105263157894737
# the probability of getting tail after  20  coin tosses is 0.39473684210526316
#
# the probability of getting head after  50  coin tosses is 0.7105263157894737
# the probability of getting tail after  50  coin tosses is 0.39473684210526316
#
#
# Round  3 :
# a =  0.3 	b =  0.7
# Task 3
# the probability of getting head after  20  coin tosses is 0.23076923076923067
# the probability of getting tail after  20  coin tosses is 0.23076923076923067
#
# the probability of getting head after  30  coin tosses is 0.23076923076923067
# the probability of getting tail after  30  coin tosses is 0.23076923076923067
#
# the probability of getting head after  50  coin tosses is 0.23076923076923067
# the probability of getting tail after  50  coin tosses is 0.23076923076923067
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 0.5
# the probability of getting tail after  10  coin tosses is 0.5
#
# the probability of getting head after  20  coin tosses is 0.5
# the probability of getting tail after  20  coin tosses is 0.5
#
# the probability of getting head after  50  coin tosses is 0.5
# the probability of getting tail after  50  coin tosses is 0.5
#
#
# Round  4 :
# a =  0.4 	b =  0.3
# Task 3
# the probability of getting head after  20  coin tosses is 0.16666666667397767
# the probability of getting tail after  20  coin tosses is 0.33333333333040877
#
# the probability of getting head after  30  coin tosses is 0.16666666666666657
# the probability of getting tail after  30  coin tosses is 0.33333333333333304
#
# the probability of getting head after  50  coin tosses is 0.16666666666666652
# the probability of getting tail after  50  coin tosses is 0.33333333333333304
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 0.29166728374326384
# the probability of getting tail after  10  coin tosses is 0.5833330865026942
#
# the probability of getting head after  20  coin tosses is 0.2916666666684943
# the probability of getting tail after  20  coin tosses is 0.5833333333326018
#
# the probability of getting head after  50  coin tosses is 0.2916666666666664
# the probability of getting tail after  50  coin tosses is 0.5833333333333328
#
#
# Round  5 :
# a =  0.4 	b =  0.4
# Task 3
# the probability of getting head after  20  coin tosses is 0.21052631578979103
# the probability of getting tail after  20  coin tosses is 0.3157894736840835
#
# the probability of getting head after  30  coin tosses is 0.21052631578947373
# the probability of getting tail after  30  coin tosses is 0.3157894736842105
#
# the probability of getting head after  50  coin tosses is 0.21052631578947373
# the probability of getting tail after  50  coin tosses is 0.3157894736842105
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 0.3684211360570803
# the probability of getting tail after  10  coin tosses is 0.552631545577168
#
# the probability of getting head after  20  coin tosses is 0.368421052631632
# the probability of getting tail after  20  coin tosses is 0.5526315789473475
#
# the probability of getting head after  50  coin tosses is 0.3684210526315792
# the probability of getting tail after  50  coin tosses is 0.5526315789473687
#
#
# Round  6 :
# a =  0.4 	b =  0.0
# Task 3
# the probability of getting head after  20  coin tosses is 1.0995116277760013e-08
# the probability of getting tail after  20  coin tosses is 0.39999999560195343
#
# the probability of getting head after  30  coin tosses is 1.1529215046068489e-12
# the probability of getting tail after  30  coin tosses is 0.39999999999953884
#
# the probability of getting head after  50  coin tosses is 1.2676506002282326e-20
# the probability of getting tail after  50  coin tosses is 0.4
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 5.242880000000003e-05
# the probability of getting tail after  10  coin tosses is 0.6999790284799999
#
# the probability of getting head after  20  coin tosses is 5.497558138880006e-09
# the probability of getting tail after  20  coin tosses is 0.6999999978009768
#
# the probability of getting head after  50  coin tosses is 6.338253001141163e-21
# the probability of getting tail after  50  coin tosses is 0.6999999999999997
#
#
# Round  7 :
# a =  0.3 	b =  0.2
# Task 3
# the probability of getting head after  20  coin tosses is 0.07894736842142297
# the probability of getting tail after  20  coin tosses is 0.27631578947357344
#
# the probability of getting head after  30  coin tosses is 0.07894736842105272
# the probability of getting tail after  30  coin tosses is 0.2763157894736845
#
# the probability of getting head after  50  coin tosses is 0.07894736842105272
# the probability of getting tail after  50  coin tosses is 0.2763157894736845
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 0.17105284014270056
# the probability of getting tail after  10  coin tosses is 0.5986841479571898
#
# the probability of getting head after  20  coin tosses is 0.17105263157907963
# the probability of getting tail after  20  coin tosses is 0.5986842105262762
#
# the probability of getting head after  50  coin tosses is 0.17105263157894746
# the probability of getting tail after  50  coin tosses is 0.598684210526316
#
#
# Round  8 :
# a =  0.9 	b =  0.6
# Task 3
# the probability of getting head after  20  coin tosses is 0.8437500002088671
# the probability of getting tail after  20  coin tosses is 0.1406249998120196
#
# the probability of getting head after  30  coin tosses is 0.8437500000000077
# the probability of getting tail after  30  coin tosses is 0.1406249999999931
#
# the probability of getting head after  50  coin tosses is 0.84375
# the probability of getting tail after  50  coin tosses is 0.14062499999999994
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 0.8906107181310938
# the probability of getting tail after  10  coin tosses is 0.14845035368201587
#
# the probability of getting head after  20  coin tosses is 0.8906249994778324
# the probability of getting tail after  20  coin tosses is 0.14843750046995097
#
# the probability of getting head after  50  coin tosses is 0.8906250000000001
# the probability of getting tail after  50  coin tosses is 0.1484375
#
#
# Round  9 :
# a =  0.7 	b =  0.9
# Task 3
# the probability of getting head after  20  coin tosses is 0.6774193548387096
# the probability of getting tail after  20  coin tosses is 0.22580645161290325
#
# the probability of getting head after  30  coin tosses is 0.6774193548387096
# the probability of getting tail after  30  coin tosses is 0.22580645161290325
#
# the probability of getting head after  50  coin tosses is 0.6774193548387096
# the probability of getting tail after  50  coin tosses is 0.22580645161290325
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 0.8225806451603791
# the probability of getting tail after  10  coin tosses is 0.2741935483877347
#
# the probability of getting head after  20  coin tosses is 0.8225806451612903
# the probability of getting tail after  20  coin tosses is 0.2741935483870968
#
# the probability of getting head after  50  coin tosses is 0.8225806451612903
# the probability of getting tail after  50  coin tosses is 0.2741935483870968
#
#
# Round  10 :
# a =  0.1 	b =  0.8
# Task 3
# the probability of getting head after  20  coin tosses is 0.08163265306122452
# the probability of getting tail after  20  coin tosses is 0.0918367346938776
#
# the probability of getting head after  30  coin tosses is 0.08163265306122452
# the probability of getting tail after  30  coin tosses is 0.0918367346938776
#
# the probability of getting head after  50  coin tosses is 0.08163265306122452
# the probability of getting tail after  50  coin tosses is 0.0918367346938776
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 0.44897959183673475
# the probability of getting tail after  10  coin tosses is 0.5051020408163266
#
# the probability of getting head after  20  coin tosses is 0.44897959183673475
# the probability of getting tail after  20  coin tosses is 0.5051020408163266
#
# the probability of getting head after  50  coin tosses is 0.44897959183673475
# the probability of getting tail after  50  coin tosses is 0.5051020408163266

# %% [markdown]
# <h3>Task 8</h3>
#
# We can rewrite arbitrary GameCoins as
#
# $  \begin{array}{c|cc} \hookleftarrow & \mathbf{Head} & \mathbf{Tail} \\ \hline \mathbf{Head} & 1-y & x\\  \mathbf{Tail} & y & 1-x  \end{array} = \begin{array}{c|cc} \hookleftarrow & \mathbf{0} & \mathbf{1} \\ \hline \mathbf{0} & 1-y & x \\  \mathbf{1} & y & 1-x  \end{array}.
# $
#
# We assume that it is neither Identity nor NOT operator. Then, independent of the initial state, the system always converges to
#
# $ Pr[heads] = \dfrac{x}{x+y} $ and $ Pr[tails]=\dfrac{y}{x+y} $,
#
# which are the probabilities of getting heads and tails, respectively.
#
# Observe this fact by checking the results of Task 7.

# %%
#
# your solution is here
#
for i in range(10):
    print('Round ',i+1,':')
    a = randrange(10)/10
    b = randrange(10)/10
    print('a = ',a,'\tb = ',b)
    GameCoins(1-a,b)
    print()
# Out:
# Round  1 :
# a =  0.5 	b =  0.1
# Task 3
# the probability of getting head after  20  coin tosses is 0.09090919631321187
# the probability of getting tail after  20  coin tosses is 0.45454540184339454
#
# the probability of getting head after  30  coin tosses is 0.09090909094498179
# the probability of getting tail after  30  coin tosses is 0.4545454545275097
#
# the probability of getting head after  50  coin tosses is 0.09090909090909105
# the probability of getting tail after  50  coin tosses is 0.45454545454545525
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 0.13648745683242194
# the probability of getting tail after  10  coin tosses is 0.6817562715837895
#
# the probability of getting head after  20  coin tosses is 0.1363636785252848
# the probability of getting tail after  20  coin tosses is 0.6818181607373581
#
# the probability of getting head after  50  coin tosses is 0.13636363636363652
# the probability of getting tail after  50  coin tosses is 0.6818181818181825
#
#
# Round  2 :
# a =  0.1 	b =  0.5
# Task 3
# the probability of getting head after  20  coin tosses is 0.8181818392626425
# the probability of getting tail after  20  coin tosses is 0.16363634466362187
#
# the probability of getting head after  30  coin tosses is 0.8181818181889964
# the probability of getting tail after  30  coin tosses is 0.16363636362990325
#
# the probability of getting head after  50  coin tosses is 0.8181818181818182
# the probability of getting tail after  50  coin tosses is 0.16363636363636358
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 0.8635125431675781
# the probability of getting tail after  10  coin tosses is 0.17283871114917965
#
# the probability of getting head after  20  coin tosses is 0.8636363214747151
# the probability of getting tail after  20  coin tosses is 0.17272731067275615
#
# the probability of getting head after  50  coin tosses is 0.8636363636363632
# the probability of getting tail after  50  coin tosses is 0.17272727272727262
#
#
# Round  3 :
# a =  0.1 	b =  0.8
# Task 3
# the probability of getting head after  20  coin tosses is 0.8780487804878054
# the probability of getting tail after  20  coin tosses is 0.10975609756097549
#
# the probability of getting head after  30  coin tosses is 0.8780487804878052
# the probability of getting tail after  30  coin tosses is 0.10975609756097561
#
# the probability of getting head after  50  coin tosses is 0.8780487804878052
# the probability of getting tail after  50  coin tosses is 0.10975609756097561
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 0.9268292530528839
# the probability of getting tail after  10  coin tosses is 0.11585367225240456
#
# the probability of getting head after  20  coin tosses is 0.9268292682926825
# the probability of getting tail after  20  coin tosses is 0.11585365853658584
#
# the probability of getting head after  50  coin tosses is 0.9268292682926831
# the probability of getting tail after  50  coin tosses is 0.11585365853658536
#
#
# Round  4 :
# a =  0.1 	b =  0.5
# Task 3
# the probability of getting head after  20  coin tosses is 0.8181818392626425
# the probability of getting tail after  20  coin tosses is 0.16363634466362187
#
# the probability of getting head after  30  coin tosses is 0.8181818181889964
# the probability of getting tail after  30  coin tosses is 0.16363636362990325
#
# the probability of getting head after  50  coin tosses is 0.8181818181818182
# the probability of getting tail after  50  coin tosses is 0.16363636363636358
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 0.8635125431675781
# the probability of getting tail after  10  coin tosses is 0.17283871114917965
#
# the probability of getting head after  20  coin tosses is 0.8636363214747151
# the probability of getting tail after  20  coin tosses is 0.17272731067275615
#
# the probability of getting head after  50  coin tosses is 0.8636363636363632
# the probability of getting tail after  50  coin tosses is 0.17272727272727262
#
#
# Round  5 :
# a =  0.2 	b =  0.0
# Task 3
# the probability of getting head after  20  coin tosses is 0.011529215046068483
# the probability of getting tail after  20  coin tosses is 0.7907766279631453
#
# the probability of getting head after  30  coin tosses is 0.0012379400392853823
# the probability of getting tail after  30  coin tosses is 0.7990096479685715
#
# the probability of getting head after  50  coin tosses is 1.4272476927059634e-05
# the probability of getting tail after  50  coin tosses is 0.7999885820184579
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 0.05368709120000003
# the probability of getting tail after  10  coin tosses is 0.85705032704
#
# the probability of getting head after  20  coin tosses is 0.0057646075230342415
# the probability of getting tail after  20  coin tosses is 0.8953883139815726
#
# the probability of getting head after  50  coin tosses is 7.136238463529817e-06
# the probability of getting tail after  50  coin tosses is 0.8999942910092293
#
#
# Round  6 :
# a =  0.5 	b =  0.5
# Task 3
# the probability of getting head after  20  coin tosses is 0.33333333333393966
# the probability of getting tail after  20  coin tosses is 0.33333333333303017
#
# the probability of getting head after  30  coin tosses is 0.33333333333333337
# the probability of getting tail after  30  coin tosses is 0.33333333333333337
#
# the probability of getting head after  50  coin tosses is 0.33333333333333337
# the probability of getting tail after  50  coin tosses is 0.33333333333333337
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 0.5
# the probability of getting tail after  10  coin tosses is 0.5
#
# the probability of getting head after  20  coin tosses is 0.5
# the probability of getting tail after  20  coin tosses is 0.5
#
# the probability of getting head after  50  coin tosses is 0.5
# the probability of getting tail after  50  coin tosses is 0.5
#
#
# Round  7 :
# a =  0.9 	b =  0.8
# Task 3
# the probability of getting head after  20  coin tosses is 0.08163265306122447
# the probability of getting tail after  20  coin tosses is 0.09183673469387751
#
# the probability of getting head after  30  coin tosses is 0.08163265306122447
# the probability of getting tail after  30  coin tosses is 0.09183673469387751
#
# the probability of getting head after  50  coin tosses is 0.08163265306122447
# the probability of getting tail after  50  coin tosses is 0.09183673469387751
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 0.4489795918367346
# the probability of getting tail after  10  coin tosses is 0.5051020408163264
#
# the probability of getting head after  20  coin tosses is 0.4489795918367346
# the probability of getting tail after  20  coin tosses is 0.5051020408163264
#
# the probability of getting head after  50  coin tosses is 0.4489795918367346
# the probability of getting tail after  50  coin tosses is 0.5051020408163264
#
#
# Round  8 :
# a =  0.1 	b =  0.4
# Task 3
# the probability of getting head after  20  coin tosses is 0.7826096619641557
# the probability of getting tail after  20  coin tosses is 0.1956513042322594
#
# the probability of getting head after  30  coin tosses is 0.7826086976894736
# the probability of getting tail after  30  coin tosses is 0.19565217207947347
#
# the probability of getting head after  50  coin tosses is 0.7826086956521827
# the probability of getting tail after  50  coin tosses is 0.19565217391303524
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 0.8253994591763102
# the probability of getting tail after  10  coin tosses is 0.20714048674132096
#
# the probability of getting head after  20  coin tosses is 0.826085507053766
# the probability of getting tail after  20  coin tosses is 0.20652304365161067
#
# the probability of getting head after  50  coin tosses is 0.8260869565217257
# the probability of getting tail after  50  coin tosses is 0.20652173913044697
#
#
# Round  9 :
# a =  0.2 	b =  0.4
# Task 3
# the probability of getting head after  20  coin tosses is 0.6153847775101419
# the probability of getting tail after  20  coin tosses is 0.30769217799188636
#
# the probability of getting head after  30  coin tosses is 0.6153846154898753
# the probability of getting tail after  30  coin tosses is 0.30769230760809946
#
# the probability of getting head after  50  coin tosses is 0.6153846153846151
# the probability of getting tail after  50  coin tosses is 0.3076923076923074
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 0.6921828364190221
# the probability of getting tail after  10  coin tosses is 0.34625373086478234
#
# the probability of getting head after  20  coin tosses is 0.6923076112449291
# the probability of getting tail after  20  coin tosses is 0.3461539110040567
#
# the probability of getting head after  50  coin tosses is 0.6923076923076923
# the probability of getting tail after  50  coin tosses is 0.34615384615384603
#
#
# Round  10 :
# a =  0.5 	b =  0.9
# Task 3
# the probability of getting head after  20  coin tosses is 0.4736842105263157
# the probability of getting tail after  20  coin tosses is 0.26315789473684204
#
# the probability of getting head after  30  coin tosses is 0.4736842105263157
# the probability of getting tail after  30  coin tosses is 0.26315789473684204
#
# the probability of getting head after  50  coin tosses is 0.4736842105263157
# the probability of getting tail after  50  coin tosses is 0.26315789473684204
#
#
# Task 4
# the probability of getting head after  10  coin tosses is 0.710526315789453
# the probability of getting tail after  10  coin tosses is 0.3947368421052734
#
# the probability of getting head after  20  coin tosses is 0.7105263157894737
# the probability of getting tail after  20  coin tosses is 0.39473684210526316
#
# the probability of getting head after  50  coin tosses is 0.7105263157894737
# the probability of getting tail after  50  coin tosses is 0.39473684210526316
